# %% [markdown]
# # 4.1: pandas 基本操作

# %% [markdown]
# ## 4.1.1 : DataFrame 构建及方法

# %%
import numpy as np
stock_day_change = np.load('./stock_day_change.npy')
print(stock_day_change.shape)
# Out:
# (200, 504)

# %%
import pandas as pd
pd.DataFrame(stock_day_change).head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.576047  1.429367 -1.369109 -0.182814  1.266746 -0.482998 -0.058539
# 1  1.126897 -0.472679 -0.494335  1.207926 -0.455826  1.002237 -1.126348
# 2 -1.793725 -0.019944  0.315034 -0.670267 -0.224039  0.642730 -0.351663
# 3  1.963730 -0.450285 -1.109078  1.238038  0.492111  0.389073  0.653520
# 4 -0.707886  1.295374 -1.262005  0.429670 -1.029979 -0.207811 -1.437251
#
#         7         8         9      ...          494       495       496  \
# 0 -0.121484  0.345757 -0.878848    ...    -0.423527  0.538870 -2.176200
# 1 -0.672564  0.207215  1.519533    ...     0.402147 -1.882748  1.061325
# 2  0.059272  1.282213  0.776607    ...    -1.116204 -1.471603  0.182174
# 3 -0.669105 -2.724910 -1.270563    ...    -2.124647  0.481271 -0.800457
# 4 -1.257908  0.650735 -2.257433    ...     0.022684 -0.054452  0.745635
#
#         497       498       499       500       501       502       503
# 0  1.131408  1.221927  0.783571 -0.219622  0.474857 -1.180290  0.648657
# 1 -0.600954 -0.344520  0.703204  0.960523  0.523314  0.771721 -0.546337
# 2  0.164857  3.162968  0.435260  1.517755 -0.797487  0.098546  0.379644
# 3  1.470654 -2.088030  0.938024 -0.197565 -0.851537  0.622673  0.100300
# 4  0.277751 -1.668281  1.272771  0.731077 -1.649358  0.377490  0.176878
#
# [5 rows x 504 columns]

# %% [markdown]
# ## 4.1.2: 索引行列序列

# %%
stock_symbols = ['股票'+str(x) for x in range(stock_day_change.shape[0])]
pd.DataFrame(stock_day_change, index=stock_symbols).head(2)
# Out:
#           0         1         2         3         4         5         6    \
# 股票0 -0.576047  1.429367 -1.369109 -0.182814  1.266746 -0.482998 -0.058539
# 股票1  1.126897 -0.472679 -0.494335  1.207926 -0.455826  1.002237 -1.126348
#
#           7         8         9      ...          494       495       496  \
# 股票0 -0.121484  0.345757 -0.878848    ...    -0.423527  0.538870 -2.176200
# 股票1 -0.672564  0.207215  1.519533    ...     0.402147 -1.882748  1.061325
#
#           497       498       499       500       501       502       503
# 股票0  1.131408  1.221927  0.783571 -0.219622  0.474857 -1.180290  0.648657
# 股票1 -0.600954 -0.344520  0.703204  0.960523  0.523314  0.771721 -0.546337
#
# [2 rows x 504 columns]

# %%
days = pd.date_range('2017-1-1', periods=stock_day_change.shape[1], freq='1d')
df = pd.DataFrame(stock_day_change, index=stock_symbols, columns = days)
df.head(2)
# Out:
#      2017-01-01  2017-01-02  2017-01-03  2017-01-04  2017-01-05  2017-01-06  \
# 股票0   -0.576047    1.429367   -1.369109   -0.182814    1.266746   -0.482998
# 股票1    1.126897   -0.472679   -0.494335    1.207926   -0.455826    1.002237
#
#      2017-01-07  2017-01-08  2017-01-09  2017-01-10     ...      2018-05-10  \
# 股票0   -0.058539   -0.121484    0.345757   -0.878848     ...       -0.423527
# 股票1   -1.126348   -0.672564    0.207215    1.519533     ...        0.402147
#
#      2018-05-11  2018-05-12  2018-05-13  2018-05-14  2018-05-15  2018-05-16  \
# 股票0    0.538870   -2.176200    1.131408    1.221927    0.783571   -0.219622
# 股票1   -1.882748    1.061325   -0.600954   -0.344520    0.703204    0.960523
#
#      2018-05-17  2018-05-18  2018-05-19
# 股票0    0.474857   -1.180290    0.648657
# 股票1    0.523314    0.771721   -0.546337
#
# [2 rows x 504 columns]

# %% [markdown]
# ## 4.1.3: 金融时间序列

# %%
df = df.T
df.head()
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2017-01-01 -0.576047  1.126897 -1.793725  1.963730 -0.707886  1.182295
# 2017-01-02  1.429367 -0.472679 -0.019944 -0.450285  1.295374 -0.420519
# 2017-01-03 -1.369109 -0.494335  0.315034 -1.109078 -1.262005  0.377341
# 2017-01-04 -0.182814  1.207926 -0.670267  1.238038  0.429670 -0.255780
# 2017-01-05  1.266746 -0.455826 -0.224039  0.492111 -1.029979 -0.350733
#
#                  股票6       股票7       股票8       股票9    ...        股票190  \
# 2017-01-01 -0.099854 -0.676254  0.277180 -1.537653    ...     0.258419
# 2017-01-02 -1.389363  0.498313  1.223365  1.142486    ...    -0.448480
# 2017-01-03  1.310580 -0.913642  0.967153  0.115221    ...     2.457806
# 2017-01-04  0.379667  0.439613 -0.609661 -0.407346    ...    -0.644674
# 2017-01-05 -2.986893  1.287825  0.367350  0.319622    ...    -1.350016
#
#                股票191     股票192     股票193     股票194     股票195     股票196  \
# 2017-01-01  0.774730  2.134792  0.404204  1.884274  1.625874 -1.774025
# 2017-01-02  0.059441  0.820712 -0.605983 -2.094197 -0.221600  0.412393
# 2017-01-03 -0.079305  0.033941 -1.290841 -0.793925 -0.017061  0.922549
# 2017-01-04 -1.861572 -0.374782 -1.089140 -0.431677  1.486036 -1.624672
# 2017-01-05 -0.640273 -0.576829  0.654943 -2.105653  0.708381 -0.298659
#
#                股票197     股票198     股票199
# 2017-01-01  0.477096 -0.337802  0.927757
# 2017-01-02  0.383113 -1.071296  0.097248
# 2017-01-03 -0.576549  1.897065  0.426410
# 2017-01-04 -1.277864 -1.551673 -0.169441
# 2017-01-05  0.285363 -1.222174  1.294888
#
# [5 rows x 200 columns]

# %%
df_20 = df.resample('21D', how='mean')
df_20.head()
# Out:
# /Users/water/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2017-01-01 -0.142938 -0.131984  0.284658 -0.241584 -0.405238  0.333079
# 2017-01-22  0.056704 -0.386959  0.286393 -0.604846  0.154484 -0.520168
# 2017-02-12  0.193636  0.158047  0.142694  0.246553 -0.157272 -0.062350
# 2017-03-05 -0.274325 -0.179221  0.272086  0.260454  0.447794 -0.099054
# 2017-03-26 -0.339880  0.551367 -0.065789  0.227199  0.430983  0.012641
#
#                  股票6       股票7       股票8       股票9    ...        股票190  \
# 2017-01-01 -0.261354 -0.153086  0.294264  0.196879    ...    -0.150775
# 2017-01-22 -0.122027  0.021735  0.059327 -0.203847    ...    -0.008461
# 2017-02-12 -0.402652  0.377394  0.323529 -0.108846    ...    -0.098129
# 2017-03-05  0.085543 -0.381923 -0.238463  0.147842    ...     0.097675
# 2017-03-26  0.103033 -0.201543  0.133698  0.104018    ...     0.269977
#
#                股票191     股票192     股票193     股票194     股票195     股票196  \
# 2017-01-01 -0.070322  0.240985 -0.127485 -0.080861  0.333428 -0.207481
# 2017-01-22 -0.172232  0.017691 -0.046523  0.110635  0.155390 -0.108154
# 2017-02-12 -0.161928  0.070077 -0.164482 -0.095449 -0.093411  0.067616
# 2017-03-05 -0.128748  0.048831 -0.339408  0.076959  0.255862 -0.041902
# 2017-03-26  0.430446 -0.021454  0.090655 -0.004337 -0.114191 -0.144619
#
#                股票197     股票198     股票199
# 2017-01-01  0.415903  0.067530 -0.139235
# 2017-01-22 -0.118909  0.166258 -0.060179
# 2017-02-12  0.080538  0.259114  0.251082
# 2017-03-05 -0.042989  0.091757 -0.062261
# 2017-03-26 -0.373603  0.268481 -0.133405
#
# [5 rows x 200 columns]

# %%
df_20 = df.resample('21D').mean()
df_20.head()
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2017-01-01 -0.142938 -0.131984  0.284658 -0.241584 -0.405238  0.333079
# 2017-01-22  0.056704 -0.386959  0.286393 -0.604846  0.154484 -0.520168
# 2017-02-12  0.193636  0.158047  0.142694  0.246553 -0.157272 -0.062350
# 2017-03-05 -0.274325 -0.179221  0.272086  0.260454  0.447794 -0.099054
# 2017-03-26 -0.339880  0.551367 -0.065789  0.227199  0.430983  0.012641
#
#                  股票6       股票7       股票8       股票9    ...        股票190  \
# 2017-01-01 -0.261354 -0.153086  0.294264  0.196879    ...    -0.150775
# 2017-01-22 -0.122027  0.021735  0.059327 -0.203847    ...    -0.008461
# 2017-02-12 -0.402652  0.377394  0.323529 -0.108846    ...    -0.098129
# 2017-03-05  0.085543 -0.381923 -0.238463  0.147842    ...     0.097675
# 2017-03-26  0.103033 -0.201543  0.133698  0.104018    ...     0.269977
#
#                股票191     股票192     股票193     股票194     股票195     股票196  \
# 2017-01-01 -0.070322  0.240985 -0.127485 -0.080861  0.333428 -0.207481
# 2017-01-22 -0.172232  0.017691 -0.046523  0.110635  0.155390 -0.108154
# 2017-02-12 -0.161928  0.070077 -0.164482 -0.095449 -0.093411  0.067616
# 2017-03-05 -0.128748  0.048831 -0.339408  0.076959  0.255862 -0.041902
# 2017-03-26  0.430446 -0.021454  0.090655 -0.004337 -0.114191 -0.144619
#
#                股票197     股票198     股票199
# 2017-01-01  0.415903  0.067530 -0.139235
# 2017-01-22 -0.118909  0.166258 -0.060179
# 2017-02-12  0.080538  0.259114  0.251082
# 2017-03-05 -0.042989  0.091757 -0.062261
# 2017-03-26 -0.373603  0.268481 -0.133405
#
# [5 rows x 200 columns]

# %% [markdown]
# ## 4.1.4 Series 构建及方法

# %%
df_stock0 = df['股票0']
print(df_stock0.head())
print(type(df_stock0))
# Out:
# 2017-01-01   -0.576047
# 2017-01-02    1.429367
# 2017-01-03   -1.369109
# 2017-01-04   -0.182814
# 2017-01-05    1.266746
# Freq: D, Name: 股票0, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
df_stock0.cumsum().plot()

# %%
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# ## 4.1.5 重采样数据

# %%
df_stock0_5 = df_stock0.cumsum().resample('5D', how='ohlc')
df_stock0_21 = df_stock0.cumsum().resample('21D', how='ohlc')
df_stock0_5.head()
# Out:
# /Users/water/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).ohlc()
#   """Entry point for launching an IPython kernel.
# /Users/water/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).ohlc()
#                 open      high       low     close
# 2017-01-01 -0.576047  0.853320 -0.698603  0.568143
# 2017-01-06  0.085145  0.250879 -0.627970 -0.627970
# 2017-01-11 -1.078619  1.864558 -1.078619  1.864558
# 2017-01-16  0.530305  0.656519  0.143120  0.143120
# 2017-01-21 -3.001701 -2.617140 -3.201946 -2.733596

# %%
df_stock0_5 = df_stock0.cumsum().resample('5D').ohlc()
df_stock0_21 = df_stock0.cumsum().resample('21D').ohlc()
df_stock0_5.head()
# Out:
#                 open      high       low     close
# 2017-01-01 -0.576047  0.853320 -0.698603  0.568143
# 2017-01-06  0.085145  0.250879 -0.627970 -0.627970
# 2017-01-11 -1.078619  1.864558 -1.078619  1.864558
# 2017-01-16  0.530305  0.656519  0.143120  0.143120
# 2017-01-21 -3.001701 -2.617140 -3.201946 -2.733596

# %%
print(type(df_stock0))
print(type(df_stock0_5['open'].values))
print(df_stock0_5['open'].index)
print(df_stock0_5.columns)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
# DatetimeIndex(['2017-01-01', '2017-01-06', '2017-01-11', '2017-01-16',
#                '2017-01-21', '2017-01-26', '2017-01-31', '2017-02-05',
#                '2017-02-10', '2017-02-15',
#                ...
#                '2018-04-01', '2018-04-06', '2018-04-11', '2018-04-16',
#                '2018-04-21', '2018-04-26', '2018-05-01', '2018-05-06',
#                '2018-05-11', '2018-05-16'],
#               dtype='datetime64[ns]', length=101, freq='5D')
# Index(['open', 'high', 'low', 'close'], dtype='object')

# %% [markdown]
# # 4.2 基本数据分析示例

# %%
from abupy import ABuSymbolPd
tsla_df = ABuSymbolPd.make_kl_df('usTSLA', n_folds=2)
tsla_df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-43fea4a11eb6> in <module>()
#       1 from abupy import ABuSymbolPd
#       2 tsla_df = ABuSymbolPd.make_kl_df('usTSLA', n_folds=2)
# ----> 3 tsla_df.tail()
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
from abupy import ABuSymbolPd
import abupy

abupy.env.enable_example_env_ipython()

tsla_df = ABuSymbolPd.make_kl_df('usTSLA', n_folds=2)
print(tsla_df.tail())
# Out:
# enable example env will only read RomDataBu/csv
#              close     high     low  p_change    open  pre_close   volume  \
# 2016-07-20  228.36  229.800  225.00      1.38  226.47     225.26  2568498
# 2016-07-21  220.50  227.847  219.10     -3.44  226.00     228.36  4428651
# 2016-07-22  222.27  224.500  218.88      0.80  221.99     220.50  2579692
# 2016-07-25  230.01  231.390  221.37      3.48  222.27     222.27  4490683
# 2016-07-26  225.93  228.740  225.63     -1.77  227.34     230.01    41833
#
#                 date  date_week  key   atr21   atr14
# 2016-07-20  20160720          2  499  9.1923  8.7234
# 2016-07-21  20160721          3  500  9.1711  8.7251
# 2016-07-22  20160722          4  501  9.1858  8.7790
# 2016-07-25  20160725          0  502  9.2669  8.9298
# 2016-07-26  20160726          1  503  9.1337  8.7541

# %% [markdown]
# ## 4.2.1: 总览分析数据

# %%
tsla_df[['close', 'volume']].plot(subplots=True, style=['r', 'g'], grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa473aab9b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa473c6f9e8>], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.show()

# %%
tsla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 504 entries, 2014-07-23 to 2016-07-26
# Data columns (total 12 columns):
# close        504 non-null float64
# high         504 non-null float64
# low          504 non-null float64
# p_change     504 non-null float64
# open         504 non-null float64
# pre_close    504 non-null float64
# volume       504 non-null int64
# date         504 non-null int64
# date_week    504 non-null int64
# key          504 non-null int64
# atr21        504 non-null float64
# atr14        504 non-null float64
# dtypes: float64(8), int64(4)
# memory usage: 51.2 KB

# %%
tsla_df.describe()
# Out:
#           close      high       low  p_change      open  pre_close  \
# count  504.0000  504.0000  504.0000  504.0000  504.0000   504.0000
# mean   228.4653  232.1352  224.5626    0.0375  228.4258   228.4587
# std     25.4947   25.2726   25.6123    2.6076   25.5300    25.5050
# min    143.6700  154.9700  141.0500  -10.4500  142.3200   143.6700
# 25%    210.3100  214.5175  207.0700   -1.2525  210.7175   210.3100
# 50%    227.6150  231.8250  223.4300    0.0650  227.8250   227.6150
# 75%    248.4800  251.9100  245.5575    1.3700  248.8525   248.4800
# max    286.0400  291.4200  280.4000   11.1700  287.6700   286.0400
#
#            volume        date  date_week       key     atr21     atr14
# count  5.0400e+02  5.0400e+02   504.0000  504.0000  504.0000  504.0000
# mean   4.9038e+06  2.0151e+07     2.0159  251.5000   10.2617   10.2592
# std    2.6580e+06  6.8708e+03     1.3986  145.6365    1.5960    1.8714
# min    4.1833e+04  2.0141e+07     0.0000    0.0000    6.7806    6.2251
# 25%    3.1852e+06  2.0150e+07     1.0000  125.7500    9.1850    9.0220
# 50%    4.2418e+06  2.0151e+07     2.0000  251.5000   10.0495   10.0609
# 75%    5.8039e+06  2.0160e+07     3.0000  377.2500   11.4082   11.3879
# max    2.3742e+07  2.0161e+07     4.0000  503.0000   14.9311   16.6603

# %% [markdown]
# ## 4.2.2 索引选取和切片选择

# %%
tsla_df.loc['2014-07-23':'2014-07-31', 'open']
# Out:
# 2014-07-23    220.01
# 2014-07-24    223.25
# 2014-07-25    222.72
# 2014-07-28    224.25
# 2014-07-29    226.61
# 2014-07-30    221.92
# 2014-07-31    229.26
# Name: open, dtype: float64

# %%
tsla_df.loc['2014-07-23':'2014-07-31']
# Out:
#              close    high     low  p_change    open  pre_close   volume  \
# 2014-07-23  222.49  224.75  219.43      1.33  220.01     219.58  3088731
# 2014-07-24  223.54  225.10  220.80      0.47  223.25     222.49  3248410
# 2014-07-25  223.57  226.97  221.75      0.01  222.72     223.54  3090383
# 2014-07-28  224.82  232.00  221.40      0.56  224.25     223.57  6517611
# 2014-07-29  225.01  228.30  224.86      0.08  226.61     224.82  3387187
# 2014-07-30  228.92  229.60  221.04      1.74  221.92     225.01  4927823
# 2014-07-31  223.30  231.40  221.50     -2.45  229.26     228.92  7749058
#
#                 date  date_week  key   atr21   atr14
# 2014-07-23  20140723          2    0  8.9775  8.4591
# 2014-07-24  20140724          3    1  8.8129  8.2492
# 2014-07-25  20140725          4    2  8.6418  8.0328
# 2014-07-28  20140728          0    3  8.7351  8.2162
# 2014-07-29  20140729          1    4  8.5443  7.9672
# 2014-07-30  20140730          2    5  8.5451  8.0095
# 2014-07-31  20140731          3    6  8.6096  8.1445

# %%
tsla_df.iloc[1:6, 2:6]
# Out:
#                low  p_change    open  pre_close
# 2014-07-24  220.80      0.47  223.25     222.49
# 2014-07-25  221.75      0.01  222.72     223.54
# 2014-07-28  221.40      0.56  224.25     223.57
# 2014-07-29  224.86      0.08  226.61     224.82
# 2014-07-30  221.04      1.74  221.92     225.01

# %% [markdown]
# ## 4.2.3 逻辑条件进行数据筛选

# %%
tsla_df[(np.abs(tsla_df.p_change) > 8) & (tsla_df.volume > 2.5 * tsla_df.volume.mean())]
# Out:
#              close    high     low  p_change    open  pre_close    volume  \
# 2014-09-15  253.86  274.40  249.13     -9.08  274.37     279.20  16464949
# 2015-08-06  246.13  255.00  236.12     -8.88  249.54     270.13  14623754
# 2015-11-04  231.63  232.74  225.20     11.17  227.00     208.35  12726366
# 2016-06-22  196.66  205.95  195.75    -10.45  199.47     219.61  23742414
#
#                 date  date_week  key    atr21    atr14
# 2014-09-15  20140915          0   37   9.9963  10.4530
# 2015-08-06  20150806          3  261  10.7972  11.5946
# 2015-11-04  20151104          2  324  11.1504  10.8725
# 2016-06-22  20160622          2  481   9.8900   9.8683

# %% [markdown]
# ## 4.2.4 数据序列值排序

# %%
tsla_df.sort_index(by='p_change')[:5]
# Out:
#              close    high     low  p_change     open  pre_close    volume  \
# 2016-06-22  196.66  205.95  195.75    -10.45  199.470     219.61  23742414
# 2014-09-15  253.86  274.40  249.13     -9.08  274.370     279.20  16464949
# 2016-02-08  147.99  157.15  146.00     -8.99  157.105     162.61   9312988
# 2015-08-06  246.13  255.00  236.12     -8.88  249.540     270.13  14623754
# 2014-10-10  236.91  245.89  235.20     -7.82  244.640     257.01  12898280
#
#                 date  date_week  key    atr21    atr14
# 2016-06-22  20160622          2  481   9.8900   9.8683
# 2014-09-15  20140915          0   37   9.9963  10.4530
# 2016-02-08  20160208          0  388  12.3292  13.3551
# 2015-08-06  20150806          3  261  10.7972  11.5946
# 2014-10-10  20141010          4   56  10.8987  11.3338

# %%
tsla_df.sort_index(by='p_change', ascending=False)[:5]
# Out:
#              close    high     low  p_change    open  pre_close    volume  \
# 2015-11-04  231.63  232.74  225.20     11.17  227.00     208.35  12726366
# 2014-10-28  242.77  244.60  228.25      9.52  229.60     221.67  10516300
# 2016-02-17  168.68  169.34  156.68      8.71  159.00     155.17   5825159
# 2015-08-27  242.99  244.75  230.81      8.07  231.00     224.84   7655959
# 2016-02-22  177.74  178.91  169.85      6.70  170.12     166.58   5055340
#
#                 date  date_week  key    atr21    atr14
# 2015-11-04  20151104          2  324  11.1504  10.8725
# 2014-10-28  20141028          1   68  11.2590  11.4392
# 2016-02-17  20160217          2  394  13.2054  14.2134
# 2015-08-27  20150827          3  276  14.3472  15.8950
# 2016-02-22  20160222          0  397  13.0337  13.7522

# %%
tsla_df.dropna()

# %%
tsla_df.dropna(how='all')
# Out:
#              close     high     low  p_change    open  pre_close    volume  \
# 2014-07-23  222.49  224.750  219.43      1.33  220.01     219.58   3088731
# 2014-07-24  223.54  225.100  220.80      0.47  223.25     222.49   3248410
# 2014-07-25  223.57  226.970  221.75      0.01  222.72     223.54   3090383
# 2014-07-28  224.82  232.000  221.40      0.56  224.25     223.57   6517611
# 2014-07-29  225.01  228.300  224.86      0.08  226.61     224.82   3387187
# 2014-07-30  228.92  229.600  221.04      1.74  221.92     225.01   4927823
# 2014-07-31  223.30  231.400  221.50     -2.45  229.26     228.92   7749058
# 2014-08-01  233.27  237.500  226.00      4.46  226.09     223.30  11898130
# 2014-08-04  238.52  240.500  233.27      2.25  234.38     233.27   5967406
# 2014-08-05  238.49  242.990  235.69     -0.01  237.47     238.52   5388581
# ...            ...      ...     ...       ...     ...        ...       ...
# 2016-07-13  222.53  225.590  220.29     -0.94  225.50     224.65   3567062
# 2016-07-14  221.53  224.940  221.05     -0.45  223.12     222.53   2675834
# 2016-07-15  220.40  222.750  219.64     -0.51  222.52     221.53   2234247
# 2016-07-18  226.25  227.090  218.30      2.65  219.64     220.40   3412055
# 2016-07-19  225.26  229.100  224.75     -0.44  225.00     226.25   3115065
# 2016-07-20  228.36  229.800  225.00      1.38  226.47     225.26   2568498
# 2016-07-21  220.50  227.847  219.10     -3.44  226.00     228.36   4428651
# 2016-07-22  222.27  224.500  218.88      0.80  221.99     220.50   2579692
# 2016-07-25  230.01  231.390  221.37      3.48  222.27     222.27   4490683
# 2016-07-26  225.93  228.740  225.63     -1.77  227.34     230.01     41833
#
#                 date  date_week  key    atr21   atr14
# 2014-07-23  20140723          2    0   8.9775  8.4591
# 2014-07-24  20140724          3    1   8.8129  8.2492
# 2014-07-25  20140725          4    2   8.6418  8.0328
# 2014-07-28  20140728          0    3   8.7351  8.2162
# 2014-07-29  20140729          1    4   8.5443  7.9672
# 2014-07-30  20140730          2    5   8.5451  8.0095
# 2014-07-31  20140731          3    6   8.6096  8.1445
# 2014-08-01  20140801          4    7   8.7472  8.3842
# 2014-08-04  20140804          0    8   9.1498  9.0139
# 2014-08-05  20140805          1    9   9.1769  9.0643
# ...              ...        ...  ...      ...     ...
# 2016-07-13  20160713          2  494  10.0943  9.9625
# 2016-07-14  20160714          3  495   9.7989  9.5287
# 2016-07-15  20160715          4  496   9.4804  9.0702
# 2016-07-18  20160718          0  497   9.4475  9.0502
# 2016-07-19  20160719          1  498   9.4119  9.0252
# 2016-07-20  20160720          2  499   9.1923  8.7234
# 2016-07-21  20160721          3  500   9.1711  8.7251
# 2016-07-22  20160722          4  501   9.1858  8.7790
# 2016-07-25  20160725          0  502   9.2669  8.9298
# 2016-07-26  20160726          1  503   9.1337  8.7541
#
# [504 rows x 12 columns]

# %%
tsla_df.fillna(tsla_df.mean(), inplace=True)

# %%
tsla_df.close[:3]
# Out:
# 2014-07-23    222.49
# 2014-07-24    223.54
# 2014-07-25    223.57
# Name: close, dtype: float64

# %%
tsla_df.close.pct_change()[:3]
# Out:
# 2014-07-23       NaN
# 2014-07-24    0.0047
# 2014-07-25    0.0001
# Name: close, dtype: float64

# %%
print((223.57-223.54)/223.54)
# Out:
# 0.00013420416927619727

# %%
change_ratio = tsla_df.close.pct_change()
change_ratio.tail()
# Out:
# 2016-07-20    0.0138
# 2016-07-21   -0.0344
# 2016-07-22    0.0080
# 2016-07-25    0.0348
# 2016-07-26   -0.0177
# Name: close, dtype: float64

# %%
np.round(change_ratio[-5:]*100, 2)
# Out:
# 2016-07-20    1.38
# 2016-07-21   -3.44
# 2016-07-22    0.80
# 2016-07-25    3.48
# 2016-07-26   -1.77
# Name: close, dtype: float64

# %% [markdown]
# 这里的format做了什么处理,不是很明白???

# %%
format = lambda x: '%.2f' % x
tsla_df.atr21.map(format).tail()
# Out:
# 2016-07-20    9.19
# 2016-07-21    9.17
# 2016-07-22    9.19
# 2016-07-25    9.27
# 2016-07-26    9.13
# Name: atr21, dtype: object

# %% [markdown]
# ## 4.2.5 数据本地序列化操作

# %%
tsla_df.to_csv('./gen/tsla_df.csv', columns=tsla_df.columns, index=True)

# %%
tsla_df_load = pd.read_csv('./gen/tsla_df.csv', parse_dates=True, index_col=0)
tsla_df_load.tail()
# Out:
#              close     high     low  p_change    open  pre_close   volume  \
# 2016-07-20  228.36  229.800  225.00      1.38  226.47     225.26  2568498
# 2016-07-21  220.50  227.847  219.10     -3.44  226.00     228.36  4428651
# 2016-07-22  222.27  224.500  218.88      0.80  221.99     220.50  2579692
# 2016-07-25  230.01  231.390  221.37      3.48  222.27     222.27  4490683
# 2016-07-26  225.93  228.740  225.63     -1.77  227.34     230.01    41833
#
#                 date  date_week  key   atr21   atr14
# 2016-07-20  20160720          2  499  9.1923  8.7234
# 2016-07-21  20160721          3  500  9.1711  8.7251
# 2016-07-22  20160722          4  501  9.1858  8.7790
# 2016-07-25  20160725          0  502  9.2669  8.9298
# 2016-07-26  20160726          1  503  9.1337  8.7541

# %% [markdown]
# # 4.3 寻找股票异动涨跌幅阀值

# %%
tsla_df.p_change.hist(bins=80)

# %%
plt.show()

# %%
cats = pd.qcut(np.abs(tsla_df.p_change), 10)
cats.value_counts()
# Out:
# (4.221, 11.17]    51
# (2.324, 3.01]     51
# (1.764, 2.324]    51
# (0.72, 1.04]      51
# (0.436, 0.72]     51
# (0.009, 0.192]    51
# (1.34, 1.764]     50
# (0.192, 0.436]    50
# (3.01, 4.221]     49
# (1.04, 1.34]      49
# Name: p_change, dtype: int64

# %% [markdown]
# ## 4.3.1 数据的离散化

# %%
bins = [-np.inf, -7.0, -5, -3, 0, 3,5,7, np.inf]
cats = pd.cut(tsla_df.p_change, bins)
cats.value_counts()
# Out:
# (0.0, 3.0]      209
# (-3.0, 0.0]     193
# (3.0, 5.0]       38
# (-5.0, -3.0]     35
# (5.0, 7.0]        9
# (-7.0, -5.0]      9
# (-inf, -7.0]      7
# (7.0, inf]        4
# Name: p_change, dtype: int64

# %%
change_ration_dummies = pd.get_dummies(cats, prefix='cr_dummies')
change_ration_dummies.tail()
# Out:
#             cr_dummies_(-inf, -7.0]  cr_dummies_(-7.0, -5.0]  \
# 2016-07-20                        0                        0
# 2016-07-21                        0                        0
# 2016-07-22                        0                        0
# 2016-07-25                        0                        0
# 2016-07-26                        0                        0
#
#             cr_dummies_(-5.0, -3.0]  cr_dummies_(-3.0, 0.0]  \
# 2016-07-20                        0                       0
# 2016-07-21                        1                       0
# 2016-07-22                        0                       0
# 2016-07-25                        0                       0
# 2016-07-26                        0                       1
#
#             cr_dummies_(0.0, 3.0]  cr_dummies_(3.0, 5.0]  \
# 2016-07-20                      1                      0
# 2016-07-21                      0                      0
# 2016-07-22                      1                      0
# 2016-07-25                      0                      1
# 2016-07-26                      0                      0
#
#             cr_dummies_(5.0, 7.0]  cr_dummies_(7.0, inf]
# 2016-07-20                      0                      0
# 2016-07-21                      0                      0
# 2016-07-22                      0                      0
# 2016-07-25                      0                      0
# 2016-07-26                      0                      0

# %% [markdown]
# ## 4.3.2 concat ,append,和merge和使用

# %%
pd.concat([tsla_df, change_ration_dummies], axis=1).tail()
# Out:
#              close     high     low  p_change    open  pre_close   volume  \
# 2016-07-20  228.36  229.800  225.00      1.38  226.47     225.26  2568498
# 2016-07-21  220.50  227.847  219.10     -3.44  226.00     228.36  4428651
# 2016-07-22  222.27  224.500  218.88      0.80  221.99     220.50  2579692
# 2016-07-25  230.01  231.390  221.37      3.48  222.27     222.27  4490683
# 2016-07-26  225.93  228.740  225.63     -1.77  227.34     230.01    41833
#
#                 date  date_week  key   atr21   atr14  cr_dummies_(-inf, -7.0]  \
# 2016-07-20  20160720          2  499  9.1923  8.7234                        0
# 2016-07-21  20160721          3  500  9.1711  8.7251                        0
# 2016-07-22  20160722          4  501  9.1858  8.7790                        0
# 2016-07-25  20160725          0  502  9.2669  8.9298                        0
# 2016-07-26  20160726          1  503  9.1337  8.7541                        0
#
#             cr_dummies_(-7.0, -5.0]  cr_dummies_(-5.0, -3.0]  \
# 2016-07-20                        0                        0
# 2016-07-21                        0                        1
# 2016-07-22                        0                        0
# 2016-07-25                        0                        0
# 2016-07-26                        0                        0
#
#             cr_dummies_(-3.0, 0.0]  cr_dummies_(0.0, 3.0]  \
# 2016-07-20                       0                      1
# 2016-07-21                       0                      0
# 2016-07-22                       0                      1
# 2016-07-25                       0                      0
# 2016-07-26                       1                      0
#
#             cr_dummies_(3.0, 5.0]  cr_dummies_(5.0, 7.0]  \
# 2016-07-20                      0                      0
# 2016-07-21                      0                      0
# 2016-07-22                      0                      0
# 2016-07-25                      1                      0
# 2016-07-26                      0                      0
#
#             cr_dummies_(7.0, inf]
# 2016-07-20                      0
# 2016-07-21                      0
# 2016-07-22                      0
# 2016-07-25                      0
# 2016-07-26                      0

# %%
pd.concat([tsla_df[tsla_df.p_change > 10], tsla_df[tsla_df.atr14 > 16]], axis = 0)
# Out:
#              close    high     low  p_change    open  pre_close    volume  \
# 2015-11-04  231.63  232.74  225.20     11.17  227.00     208.35  12726366
# 2015-08-28  248.48  251.45  241.57      2.26  241.86     242.99   5513673
# 2015-08-31  249.06  254.95  245.51      0.23  245.62     248.48   4700232
#
#                 date  date_week  key    atr21    atr14
# 2015-11-04  20151104          2  324  11.1504  10.8725
# 2015-08-28  20150828          4  277  14.9311  16.6603
# 2015-08-31  20150831          0  278  14.7897  16.3246

# %%
tsla_df[tsla_df.p_change > 10].append(tsla_df[tsla_df.atr14 > 16])
# Out:
#              close    high     low  p_change    open  pre_close    volume  \
# 2015-11-04  231.63  232.74  225.20     11.17  227.00     208.35  12726366
# 2015-08-28  248.48  251.45  241.57      2.26  241.86     242.99   5513673
# 2015-08-31  249.06  254.95  245.51      0.23  245.62     248.48   4700232
#
#                 date  date_week  key    atr21    atr14
# 2015-11-04  20151104          2  324  11.1504  10.8725
# 2015-08-28  20150828          4  277  14.9311  16.6603
# 2015-08-31  20150831          0  278  14.7897  16.3246

# %% [markdown]
# 使用concat 和 append 获取相同的结果, merge如何使用

# %%
stock_a = pd.DataFrame({'stock_a': ['a', 'b', 'c', 'd', 'a'], 'data':range(5)})
stock_b = pd.DataFrame({'stock_b': ['a', 'b', 'c'], 'data2':range(3)})
pd.merge(stock_a, stock_b, left_on = 'stock_a', right_on = 'stock_b')
# Out:
#    data stock_a  data2 stock_b
# 0     0       a      0       a
# 1     4       a      0       a
# 2     1       b      1       b
# 3     2       c      2       c

# %% [markdown]
# # 4.4 : 星期几事这个股票最好的日子?

# %%
tsla_df['positive'] = np.where(tsla_df.p_change > 0, 1, 0)
tsla_df
# Out:
#              close     high     low  p_change    open  pre_close    volume  \
# 2014-07-23  222.49  224.750  219.43      1.33  220.01     219.58   3088731
# 2014-07-24  223.54  225.100  220.80      0.47  223.25     222.49   3248410
# 2014-07-25  223.57  226.970  221.75      0.01  222.72     223.54   3090383
# 2014-07-28  224.82  232.000  221.40      0.56  224.25     223.57   6517611
# 2014-07-29  225.01  228.300  224.86      0.08  226.61     224.82   3387187
# 2014-07-30  228.92  229.600  221.04      1.74  221.92     225.01   4927823
# 2014-07-31  223.30  231.400  221.50     -2.45  229.26     228.92   7749058
# 2014-08-01  233.27  237.500  226.00      4.46  226.09     223.30  11898130
# 2014-08-04  238.52  240.500  233.27      2.25  234.38     233.27   5967406
# 2014-08-05  238.49  242.990  235.69     -0.01  237.47     238.52   5388581
# ...            ...      ...     ...       ...     ...        ...       ...
# 2016-07-13  222.53  225.590  220.29     -0.94  225.50     224.65   3567062
# 2016-07-14  221.53  224.940  221.05     -0.45  223.12     222.53   2675834
# 2016-07-15  220.40  222.750  219.64     -0.51  222.52     221.53   2234247
# 2016-07-18  226.25  227.090  218.30      2.65  219.64     220.40   3412055
# 2016-07-19  225.26  229.100  224.75     -0.44  225.00     226.25   3115065
# 2016-07-20  228.36  229.800  225.00      1.38  226.47     225.26   2568498
# 2016-07-21  220.50  227.847  219.10     -3.44  226.00     228.36   4428651
# 2016-07-22  222.27  224.500  218.88      0.80  221.99     220.50   2579692
# 2016-07-25  230.01  231.390  221.37      3.48  222.27     222.27   4490683
# 2016-07-26  225.93  228.740  225.63     -1.77  227.34     230.01     41833
#
#                 date  date_week  key    atr21   atr14  positive
# 2014-07-23  20140723          2    0   8.9775  8.4591         1
# 2014-07-24  20140724          3    1   8.8129  8.2492         1
# 2014-07-25  20140725          4    2   8.6418  8.0328         1
# 2014-07-28  20140728          0    3   8.7351  8.2162         1
# 2014-07-29  20140729          1    4   8.5443  7.9672         1
# 2014-07-30  20140730          2    5   8.5451  8.0095         1
# 2014-07-31  20140731          3    6   8.6096  8.1445         0
# 2014-08-01  20140801          4    7   8.7472  8.3842         1
# 2014-08-04  20140804          0    8   9.1498  9.0139         1
# 2014-08-05  20140805          1    9   9.1769  9.0643         0
# ...              ...        ...  ...      ...     ...       ...
# 2016-07-13  20160713          2  494  10.0943  9.9625         0
# 2016-07-14  20160714          3  495   9.7989  9.5287         0
# 2016-07-15  20160715          4  496   9.4804  9.0702         0
# 2016-07-18  20160718          0  497   9.4475  9.0502         1
# 2016-07-19  20160719          1  498   9.4119  9.0252         0
# 2016-07-20  20160720          2  499   9.1923  8.7234         1
# 2016-07-21  20160721          3  500   9.1711  8.7251         0
# 2016-07-22  20160722          4  501   9.1858  8.7790         1
# 2016-07-25  20160725          0  502   9.2669  8.9298         1
# 2016-07-26  20160726          1  503   9.1337  8.7541         0
#
# [504 rows x 13 columns]

# %% [markdown]
# ## 4.4.1 : 构建交叉表

# %%
xt = pd.crosstab(tsla_df.date_week, tsla_df.positive)
xt
# Out:
# positive    0   1
# date_week
# 0          44  51
# 1          55  48
# 2          48  57
# 3          44  57
# 4          53  47

# %%
xt_pct = xt.div(xt.sum(1).astype(float), axis=0)
xt_pct
# Out:
# positive        0       1
# date_week
# 0          0.4632  0.5368
# 1          0.5340  0.4660
# 2          0.4571  0.5429
# 3          0.4356  0.5644
# 4          0.5300  0.4700

# %%
xt_pct.plot(figsize=(8,5), kind='bar', stacked=True, title='date_week -> positive')
plt.xlabel('date_week')
plt.ylabel('positive')

# %%
plt.show()

# %% [markdown]
# ## 4.4.2 构建透视图

# %%
tsla_df.pivot_table(['positive'], index=['date_week'])
# Out:
#            positive
# date_week
# 0            0.5368
# 1            0.4660
# 2            0.5429
# 3            0.5644
# 4            0.4700

# %%
tsla_df.groupby(['date_week', 'positive'])['positive'].count()
# Out:
# date_week  positive
# 0          0           44
#            1           51
# 1          0           55
#            1           48
# 2          0           48
#            1           57
# 3          0           44
#            1           57
# 4          0           53
#            1           47
# Name: positive, dtype: int64

# %% [markdown]
# # 4.5 跳空缺口

# %%
jump_threshold = tsla_df.close.median() * 0.03
jump_threshold
# Out:
# 6.82845

# %%
jump_pd = pd.DataFrame()
def judge_jump(today):
    global jump_pd
    if today.p_change > 0 and (today.low - today.pre_close) > jump_threshold:
        today['jump'] = 1
        today['jump_power'] = (today.low - today.pre_close) / jump_threshold
        jump_pd = jump_pd.append(today)
    elif today.p_change < 0 and (today.pre_close - today.high) > jump_threshold:
        today['jump'] = -1
        today['jump_power'] = (today.high - today.pre_close) / jump_threshold
        jump_pd = jump_pd.append(today)

for kl_index in np.arange(0, tsla_df.shape[0]):
    today = tsla_df.ix[kl_index]
    judge_jump(today)
jump_pd.filter(['jump', 'jump_power', 'close', 'date', 'p_change', 'pre_close'])
# Out:
#             jump  jump_power   close        date  p_change  pre_close
# 2014-08-11   1.0      1.0061  259.32  2.0141e+07      4.51     248.13
# 2014-10-10  -1.0     -1.6285  236.91  2.0141e+07     -7.82     257.01
# 2015-01-14  -1.0     -1.3253  192.69  2.0150e+07     -5.66     204.25
# 2015-02-12  -1.0     -1.4223  202.88  2.0150e+07     -4.66     212.80
# 2015-07-08  -1.0     -1.0368  254.96  2.0151e+07     -4.82     267.88
# 2015-07-21  -1.0     -1.2829  266.77  2.0151e+07     -5.49     282.26
# 2015-08-06  -1.0     -2.2157  246.13  2.0151e+07     -8.88     270.13
# 2015-08-17   1.0      1.0778  254.99  2.0151e+07      4.87     243.15
# 2015-11-04   1.0      2.4676  231.63  2.0151e+07     11.17     208.35
# 2016-01-04  -1.0     -1.2638  223.41  2.0160e+07     -6.92     240.01
# 2016-06-22  -1.0     -2.0005  196.66  2.0161e+07    -10.45     219.61

# %%
jump_pd = pd.DataFrame()
tsla_df.apply(judge_jump, axis=1)
from abupy import ABuMarketDrawing
ABuMarketDrawing.plot_candle_form_klpd(tsla_df, view_indexs=jump_pd.index)

# %% [markdown]
# 不是很明白实现原理?

# %% [markdown]
# # 4.6 pandas 三维面板的使用

# %%
from abupy import ABuIndustries
r_symbol='usTSLA'
p_date, _ = ABuIndustries.get_industries_panel_from_target(r_symbol, show=False)
type(p_date)
# p_date['usTTM'].head()
p_date
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 1 (items) x 504 (major_axis) x 12 (minor_axis)
# Items axis: usTSLA to usTSLA
# Major_axis axis: 2014-07-23 00:00:00 to 2016-07-26 00:00:00
# Minor_axis axis: close to atr14

# %%
p_date['usTTM'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'usTTM'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-a0eea5f41399> in <module>()
# ----> 1 p_date['usTTM'].head()
#
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/panel.py in __getitem__(self, key)
#     284             return self._getitem_multilevel(key)
#     285         if not (is_list_like(key) or isinstance(key, slice)):
# --> 286             return super(Panel, self).__getitem__(key)
#     287         return self.loc[key]
#     288
#
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getitem__(self, item)
#    1525
#    1526     def __getitem__(self, item):
# -> 1527         return self._get_item_cache(item)
#    1528
#    1529     def _get_item_cache(self, item):
#
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/water/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'usTTM'
